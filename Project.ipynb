# %%
import  pandas as pd 
import numpy as np
import time 
import warnings
import datetime
import random
from selenium import webdriver
# from selenium.common import exceptions
from selenium.webdriver import ChromeService 
import selenium
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoSuchAttributeException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait as WDW
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import ElementNotInteractableException
import re
from time import sleep
from nltk import WordNetLemmatizer
from nltk.stem import LancasterStemmer,PorterStemmer
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from pymysql import connect
import pandas as pd
from nltk.tokenize import word_tokenize,sent_tokenize
from flask import Flask,render_template,request,template_rendered
import numpy as np
from mysql.connector import connect 
from sqlalchemy import create_engine
from flask import jsonify

# %%
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# %%
driver.maximize_window()

# %%
url = 'https://www.daraz.pk/'

# %%
driver.get(url)

# %%
search_bar = driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div[1]/div/div/div[2]/div/div[2]/form/div/div[1]/input[1]')

# %%
search_bar.send_keys('Phones'+Keys.RETURN)

# %%
next_page_key = driver.find_element(By.CLASS_NAME,'ant-pagination-item-link')
# '//*[@id="root"]/div/div[3]/div/div/div[1]/div[3]/div[2]/div/ul/li[9]/a' alternate rel XPATH
# '/html/body/div[3]/div/div[3]/div/div/div[1]/div[3]/div[2]/div/ul/li[9]/a' Full XPATH

# %%
# next_page_key.click()   ##Execute this command when the first page has been scraped, DO NOT DO IT NOW

# %%
Individual_products = driver.find_elements(By.CLASS_NAME,'title--wFj93')   ## will find clickable links of 40 products on the current page

# %%
# for i in range(1,41):
#     if i == 13:
#         continue
#     base = '/html/body/div[3]/div/div[3]/div/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[2]'
#     Prod = driver.find_element(By.XPATH, base)
#     print(Prod.get_attribute('href'))
#     print(Prod.text)
#     sleep(2)
    
#     Prod.click()
#     sleep(3)
#     name = driver.find_element(By.CLASS_NAME , 'pdp-mod-product-badge-title').text
#     name = name.split(' ')
#     name = name[0]+ " "+name[1]+ " "+name[2]
#     price = driver.find_element(By.XPATH,'/html/body/div[4]/div/div[3]/div[2]/div/div[1]/div[7]/div/div/span').text
#     price = int(''.join(filter(str.isdigit, price)))
#     print(name, price)
#     driver.back()
#     sleep(2)

# %%
driver.execute_script(f'window.scrollTo(0,500)')
sleep(1)
driver.execute_script(f'window.scrollTo(500,1000)')
rev_search = driver.find_elements(By.CLASS_NAME, 'ant-select-selection-item')
print(rev_search[1].text)
rev_search[1].click()
driver.find_element(By.XPATH,'/html/body/div[4]/div/div[9]/div[1]/div[1]/div/div/div/div[3]/div[4]/ul/li[10]/div/div[2]/div/div/div/div/div/div[2]').click()
# Out:
# 3 / page

# %%
# driver.find_element(By.XPATH, '/html/body/div[4]/div/div[9]/div[1]/div[2]/div/div/div[1]/div[1]').text
# driver.execute_script(f'window.scrollTo(900,1300)')
href = driver.find_element(By.XPATH ,'/html/body/div[3]/div/div[3]/div/div/div[1]/div[2]/div[8]/div/div/div[2]/div[2]/a').get_attribute('href')
d = driver.find_element(By.XPATH ,'/html/body/div[3]/div/div[3]/div/div/div[1]/div[2]/div[8]/div/div/div[2]/div[2]/a').click()
href
# Out:
# 'https://www.daraz.pk/products/samsung-galaxy-a04s-4gb128gb-i424968324-s2012720855.html?search=1'

# %%
Product_Price = []
Product_Name = []
Product_Specs = []
Product_Brand = []
Product_Reviews = []
Product_ID = []
Product_Rating = []
Product_Link = []

for i in range(1,41):
    rating = ''
    Reviews = []
    base = '/html/body/div[3]/div/div[3]/div/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[2]/a'
#     print(base)
    
    prod = driver.find_element(By.XPATH ,base)
    
    sleep(2)
    prod.click()
    sleep(2)
    try:
#         print('hi')
        name = driver.find_element(By.CLASS_NAME,'pdp-mod-product-badge-title').text
        print(name)
        brand = driver.find_element(By.XPATH, '/html/body/div[4]/div/div[3]/div[2]/div/div[1]/div[5]/div/a[1]').text
        print(brand)
        price = driver.find_element(By.XPATH, '/html/body/div[4]/div/div[3]/div[2]/div/div[1]/div[7]/div/div/span').text
        print(price)
        price = int(''.join(filter(str.isdigit, price)))
        

        
        driver.execute_script(f'window.scrollTo(0,500)')
        sleep(1.5)        
        Product_ID.append(i+120)
        Product_Brand.append(brand)
        Product_Name.append(name)
        Product_Price.append(price)
        ###
        try:
            reviews = driver.find_elements(By.CLASS_NAME,'review-item')
            if len(reviews) >= 3:
                for j in range(len(reviews)):
                    rev = driver.find_elements(By.CLASS_NAME,'review-content-sl')
                    Reviews.append(rev[j].text)
                    print(rev[j].text,end='\n')
                    
                driver.find_element(By.XPATH,'/html/body/div[4]/div/div[9]/div[1]/div[1]/div/div/div/div[3]/div[4]/ul/li[3]').click()      
                for j in range(len(reviews)):
                    rev = driver.find_elements(By.CLASS_NAME,'review-content-sl')
                    Reviews.append(rev[j].text)
            Product_Reviews.append(Reviews)
            
        except NoSuchElementException:
            
            pass
        
            
        driver.execute_script(f'window.scrollTo(500,900)')
        if i == 19 or i == 26 or i == 31 or i== 38:
            rating = 'Null'
        else:
            rating = driver.find_element(By.CLASS_NAME , 'score').text
        print(rating)
        Product_Rating.append(rating)
        sleep(3)
        
        driver.execute_script(f'window.scrollTo(900,1300)')
        sleep(3)
        specs = driver.find_element(By.XPATH, '/html/body/div[4]/div/div[9]/div[1]/div[2]/div/div/div[1]/div[1]').text
        Product_Specs.append(specs)

        
        
        driver.back()
        
        sleep(2)
        link = driver.find_element(By.XPATH ,base).get_attribute('href')
        print(i,name, brand,price,Reviews,link,specs,rating,sep='         ',end='\n\n')
        Product_Link.append(link)
    except NoSuchElementException:
        print(i, " ", 'hello')
        pass
# Out:
# itel A60s 6.6″ HD+ Display | 8+128GB Storage | HD+ display | 8MP Dual Rear Camera
# itel
# Rs. 22,749
# Very disappointing. This phone is not 8 GB RAM as claimed. This is a 4GB + 4 GB expendable. The add should clearly state that truth. Also, it has a slow processor. an iPhone user will find it very slow. it is large screen phone. The back camera quality is good in day light but not very good in low light. Overall it is okay for the price it is being sold at. But the ad should clearly state the figures to avoid any disappointments.
# same mobile deliver hoa hai thanks 😊😊👍 I'm very happy......
# good quality nice phone I like it very much
# 4.4
# ...

# %%
print(Product_Brand)
len(Product_Brand)
# Out:
# ['itel', 'No Brand', 'No Brand', 'OPPO', 'Tecno', 'No Brand', 'Xiaomi', 'No Brand', 'No Brand', 'Infinix', 'No Brand', 'No Brand', 'No Brand', 'No Brand', 'No Brand', 'No Brand', 'Infinix', 'No Brand', 'Apple', 'No Brand', 'No Brand', 'Sparx', 'No Brand', 'No Brand', 'No Brand', 'Apple', 'No Brand', 'No Brand', 'No Brand', 'No Brand', 'No Brand', 'No Brand', 'No Brand', 'No Brand', 'No Brand', 'No Brand', 'No Brand', 'No Brand', 'No Brand', 'No Brand']
# 40

# %%
Product_ID = [i for i in range(161,201)]

# %%
print(Product_ID)
# Out:
# [161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200]

# %%
print(Product_Name)
len(Product_Name)
# Out:
# ['itel A60s 6.6″ HD+ Display | 8+128GB Storage | HD+ display | 8MP Dual Rear Camera', 'Tecno CAMON 20 8GB RAM-256GB ROM 5000MAH BATTERY PTA APPROVED OFFICIAL BRAND WARRANTY', 'Samsung Galaxy A04s 4GB - 128GB OFFICIAL PTA APPROVED OFFICIAL WARRANTY', 'OPPO A17 4GB + 64GB 5000mAh Battery', 'Tecno Camon 20 - 8GB/256GB - 64 MP Camera - 5000 mAH- Battery - 6.67"', 'Original Vivo Y85 with Box & Charger - Dual Sim Approved - Vivo Y85a - 4GB RAM Mobile - Snapdragon Mobile', 'Redmi Note 12 Pro (8GB-256GB) PTA Approved With Official 1 Year Warranty', 'Oppo A57 - 5.2" HD Display - 4GB RAM - 64GB ROM - Dual Sim - PTA Approved - Phone And Box Only (Charger, Accessories Not Included - Mix Color)', 'Sparx Neo X || 4GB RAM 64GB ROM || 50MP +2MP Camera || 5000mAh Battery || PTA Approved || 1 Year Brand Warranty', 'Infinix Smart 7 - 64GB ROM - 4GB RAM - PTA APPROVED OFFICIAL WARRANTY', 'Oppo A57 2022 - 6.5" HD Display - 4GB RAM - 64GB ROM - Dual Sim - PTA Approved - Phone And Box Only (Charger, Access
# ...

# %%
print(Product_Price)
len(Product_Price)
# Out:
# [22749, 45496, 42499, 36999, 53999, 15999, 89999, 13999, 24999, 25300, 26999, 28999, 49999, 51399, 238499, 42999, 47299, 23499, 58999, 20999, 22999, 32599, 37999, 43950, 32500, 75999, 37999, 51999, 46999, 14299, 26999, 21399, 48999, 179999, 19999, 25999, 42999, 30999, 49999, 47999]
# 40

# %%
print(Product_Rating)
len(Product_Rating)
# Out:
# ['4.4', '5.0', '4.7', '4.7', '4.7', '3.8', '4.6', '2.9', '4.6', '4.5', '4.3', '4.9', '4.7', '4.7', '4.0', '4.7', '4.5', '5.0', 'Null', '4.5', '4.9', '4.3', '4.2', '4.7', '4.8', 'Null', '4.7', '4.5', '4.8', '3.6', 'Null', '4.9', '4.9', '5.0', '4.8', '5.0', '5.0', 'Null', '5.0', '1.0']
# 40

# %%
print(Product_Specs)
len(Product_Specs)
# Out:
# ['6.6″ HD+ Display\n5000mAh Battery\n8GB RAM* +128GB ROM\n8MP Dual Rear Camera\nDual Security', 'Android 13\nG85 Octa-Core\nGSM\nGPRS\nFULL EDGE\nWCDMA\nHSPA+\nTDD LTE\nFDD LTE\nAMOLED with Fingerprint on Display (6.67")\n1080*2400\nFront Camera: 32MP Dual Flash\nRear Camera: 64MP /2MP/ AI CAM/ Quad Flash(Ring-Flash)\n256GB ROM\n8GB+8GB Extended RAM\nGPS\nWiFi\nFM\nOTG\n2G\n3G\n4G\nG-Sensor\nAmbient Light and Distance Sensor\nElectronic compass\nFingerprint Sensor\n33W（Defult 18W Charger)\n5000mAh', 'Official PTA Approved\n1 Year official Warranty\nRam 4Gb\nStorage 128Gb\n6.5” HD+ Display with 90 Hz Fast Refresh Rate\nRear Cam: 50MP Main + 2MP Depth + 2MP Macro\nSide-mounted Fingerprint Sensor\nLarge Expandable Storage (up to 1TB)\n15-Watt Adaptive Fast Charging with C-Type port', 'Stylish Design Luxury and premium look\nBig Dual Eye camera\n5000 mAH big battery with 10W charging\n4GB Ram + 4GB expendable Ram\n64GB memory\n6.56" Big waterdrop screen', '8GB/256GB 64 MP Back Camera - 3
# ...

# %%
print(Product_Link)
len(Product_Link)
# Out:
# ['https://www.daraz.pk/products/itel-a60s-66-hd-display-8128gb-storage-hd-display-8mp-dual-rear-camera-i433726040-s2090405684.html?search=1', 'https://www.daraz.pk/products/20-8gb-ram-256gb-5000mah-pta-i432856844-s2101369194.html?search=1', 'https://www.daraz.pk/products/samsung-galaxy-a04s-4gb-128gb-official-pta-approved-official-warranty-i429492323-s2045838409.html?search=1', 'https://www.daraz.pk/products/oppo-a17-4gb-64gb-5000mah-battery-i422151695-s1997383387.html?search=1', 'https://www.daraz.pk/products/tecno-camon-20-8gb256gb-64-mp-camera-5000-mah-battery-667-i428102257-s2035159540.html?search=1', 'https://www.daraz.pk/products/original-vivo-y85-with-box-charger-dual-sim-approved-vivo-y85a-4gb-ram-mobile-snapdragon-mobile-i436809943-s2101413702.html?search=1', 'https://www.daraz.pk/products/12-8gb-256gb-1-pta-i429264612-s2109849787.html?search=1', 'https://www.daraz.pk/products/oppo-a57-52-hd-display-4gb-ram-64gb-rom-dual-sim-pta-approved-phone-and-box-only-charger-accessorie
# ...

# %%
print(Product_Reviews)
len(Product_Reviews)
# Out:
# [['Very disappointing. This phone is not 8 GB RAM as claimed. This is a 4GB + 4 GB expendable. The add should clearly state that truth. Also, it has a slow processor. an iPhone user will find it very slow. it is large screen phone. The back camera quality is good in day light but not very good in low light. Overall it is okay for the price it is being sold at. But the ad should clearly state the figures to avoid any disappointments.', "same mobile deliver hoa hai thanks 😊😊👍 I'm very happy......", 'good quality nice phone I like it very much', 'Very disappointing. This phone is not 8 GB RAM as claimed. This is a 4GB + 4 GB expendable. The add should clearly state that truth. Also, it has a slow processor. an iPhone user will find it very slow. it is large screen phone. The back camera quality is good in day light but not very good in low light. Overall it is okay for the price it is being sold at. But the ad should clearly state the figures to avoid any disappointments.', "same mobile
# ...

# %%
data = {
    'Product_ID'    : Product_ID,
    'Product Name'  : Product_Name,
    'Product_Link'  : Product_Link,
    'Product_Brand' : Product_Brand,
    'Product_Price' : Product_Price,
    'Product_Rating': Product_Rating,
}
rev_and_specs = {
    'Product_ID'     : Product_ID,
    'Product_Specs'  : Product_Specs,
    'Product_Reviews': Product_Reviews
}

# %%
pg1 = pd.DataFrame(data)
revpg1 = pd.DataFrame(rev_and_specs)

# %%
pg1
# Out:
#     Product_ID                                       Product Name  \
# 0          161  itel A60s 6.6″ HD+ Display | 8+128GB Storage |...
# 1          162  Tecno CAMON 20 8GB RAM-256GB ROM 5000MAH BATTE...
# 2          163  Samsung Galaxy A04s 4GB - 128GB OFFICIAL PTA A...
# 3          164                OPPO A17 4GB + 64GB 5000mAh Battery
# 4          165  Tecno Camon 20 - 8GB/256GB - 64 MP Camera - 50...
# 5          166  Original Vivo Y85 with Box & Charger - Dual Si...
# 6          167  Redmi Note 12 Pro (8GB-256GB) PTA Approved Wit...
# 7          168  Oppo A57 - 5.2" HD Display - 4GB RAM - 64GB RO...
# 8          169  Sparx Neo X || 4GB RAM 64GB ROM || 50MP +2MP C...
# 9          170  Infinix Smart 7 - 64GB ROM - 4GB RAM - PTA APP...
# 10         171  Oppo A57 2022 - 6.5" HD Display - 4GB RAM - 64...
# 11         172  Redmi 12C || 4GB Ram 128GB Rom || 6.71 Inches ...
# 12         173  Redmi Note 12 8GB Ram 128GB Rom, Display Size ...
# ...

# %%
revpg1
# Out:
#     Product_ID                                      Product_Specs  \
# 0          161  6.6″ HD+ Display\n5000mAh Battery\n8GB RAM* +1...
# 1          162  Android 13\nG85 Octa-Core\nGSM\nGPRS\nFULL EDG...
# 2          163  Official PTA Approved\n1 Year official Warrant...
# 3          164  Stylish Design Luxury and premium look\nBig Du...
# 4          165  8GB/256GB 64 MP Back Camera - 32 MP Front Came...
# 5          166  Imported New Phone with Box & Charger\nCPU mod...
# 6          167  Display: 6.67′′ FHD+ AMOLED DotDisplay – 2400 ...
# 7          168  OPPO A57 4/64 dual sim smartphone• 5.1-5.5 inc...
# 8          169  Sparx Neo X SIM Support Dual Sim, Dual Standby...
# 9          170  SMART 7Up to 7 Big RAM (Including 3GB Extended...
# 10         171  • OPPO a57 2022 with Corning Gorilla Glass 5 p...
# 11         172  BuildOSAndroid 12 OS UIMIU1 13 Dimensions168.8...
# 12         173  BuildOSAndroid 13 OS UIMIUI 14 Dimensions165.7...
# ...

# %%
pg1.to_excel('Page5.xlsx')
revpg1.to_excel('Page5 reviews_and_specs.xlsx')

# %%
page1 = pd.read_excel('Page1.xlsx',index_col='Product_ID')
page2 = pd.read_excel('Page2.xlsx',index_col='Product_ID')
page3 = pd.read_excel('Page3.xlsx',index_col='Product_ID')
page4 = pd.read_excel('Page4.xlsx',index_col='Product_ID')
page5 = pd.read_excel('Page5.xlsx',index_col='Product_ID')
page1.drop(columns='Unnamed: 0',inplace=True)
page2.drop(columns='Unnamed: 0',inplace=True)
page3.drop(columns='Unnamed: 0',inplace=True)
page4.drop(columns='Unnamed: 0',inplace=True)
page5.drop(columns='Unnamed: 0',inplace=True)

# %%
page1
# Out:
#                                                  Product Name  \
# Product_ID
# 1           Samsung A14 4GB/64GB - 5000 mAh Battery - 6.6'...
# 2           Like New Phones - Used Apple iPhone X - Silver...
# 3           Infinix Note 30 Pro 8-256 GB PTA Approved With...
# 4           Redmi Note 12 8 GB RAM + 128GB ROM PTA Approve...
# 5           vivo Y17s - 6GB RAM - 128GB ROM - 5000mAh Batt...
# 6           Realme Narzo 50A Prime (4GB-128GB) PTA Approve...
# 7           Redmi A2+ - 3GB/64GB - Mediatek Helio G36 - An...
# 8                               Samsung Galaxy A04s 4GB+128GB
# 9           Like New Phones - Used Apple iPhone X - Silver...
# 10          Infinix Note 30 8GB/128GB - Android 13 - 6.78"...
# 11          Redmi A2+ 3GB - 64GB 5000mAh 10W fast charging...
# 12          Redmi note 12 8GB RAM -128GB ROM PTA APPROVED ...
# 13          Tecno SPARK 10 PRO 8GB RAM - 256GB ROM PTA APP...
# 14          Like New Phones - Used Apple iPhone SE 2nd Gen...
# ...

# %%
page2
# Out:
#                                                  Product Name  \
# Product_ID
# 41          Samsung Galaxy A04s 4GB - 128GB OFFICIAL PTA A...
# 42          Redmi 12C || 4GB Ram 128GB Rom || 6.71 Inches ...
# 43          Infinix Smart 7 - 64GB ROM - 4GB RAM - PTA APP...
# 44          vivo V29 5G - 12GB RAM - 256GB ROM - 50MP OIS ...
# 45          Tecno CAMON 20 8GB RAM-256GB ROM 5000MAH BATTE...
# 46          Redmi A2 Plus , 3GB RAM 64GB ROM , 8MP Main Ca...
# 47          Infinix Hot 30 8GB/128GB - Android 13 - 6.78" ...
# 48          Redmi Note 12 8GB Ram 128GB Rom, Display Size ...
# 49          Sparx Neo X || 4GB RAM 64GB ROM || 50MP +2MP C...
# 50          Itel A60s || 4GB + 128GB || 6.6 inches IPS Dis...
# 51          Xiaomi 13T Pro - 6.67" Inch AMOLED Display - 1...
# 52          Redmi Note 12 || 8GB Ram 128GB Rom || 6.67 Inc...
# 53          Infinix Note 30 RAM 8GB+8GB & 256GB Storage 6....
# 54           Itel S23 - 8GB Ram - 256GB Rom - 5000mAh Battery
# ...

# %%
page3
# Out:
#                                                  Product Name  \
# Product_ID
# 81          Infinix Smart 7 - 64GB ROM - 4GB RAM - PTA APP...
# 82          vivo V29 5G - 12GB RAM - 256GB ROM - 50MP OIS ...
# 83          Tecno CAMON 20 8GB RAM-256GB ROM 5000MAH BATTE...
# 84          Redmi A2 Plus , 3GB RAM 64GB ROM , 8MP Main Ca...
# 85          Infinix Hot 30 8GB/128GB - Android 13 - 6.78" ...
# 86          Redmi Note 12 8GB Ram 128GB Rom, Display Size ...
# 87          Sparx Neo X || 4GB RAM 64GB ROM || 50MP +2MP C...
# 88          Itel A60s || 4GB + 128GB || 6.6 inches IPS Dis...
# 89          Xiaomi 13T Pro - 6.67" Inch AMOLED Display - 1...
# 90          Redmi Note 12 || 8GB Ram 128GB Rom || 6.67 Inc...
# 91          Infinix Note 30 RAM 8GB+8GB & 256GB Storage 6....
# 92           Itel S23 - 8GB Ram - 256GB Rom - 5000mAh Battery
# 93          Xiaomi Note 12 , 8GB RAM 128GB ROM , 50MP Main...
# 94          Xiaomi 13T , 12GB RAM 256GB ROM , 50MP Main Ca...
# ...

# %%
page4
# Out:
#                                                  Product Name  \
# Product_ID
# 121         Samsung A14 4GB/64GB - 5000 mAh Battery - 6.6'...
# 122         Like New Phones - Used Apple iPhone X - Silver...
# 123         Infinix Note 30 Pro 8-256 GB PTA Approved With...
# 124         Redmi Note 12 8 GB RAM + 128GB ROM PTA Approve...
# 125         vivo Y17s - 6GB RAM - 128GB ROM - 5000mAh Batt...
# 126         Realme Narzo 50A Prime (4GB-128GB) PTA Approve...
# 127         Redmi A2+ - 3GB/64GB - Mediatek Helio G36 - An...
# 128                             Samsung Galaxy A04s 4GB+128GB
# 129         Infinix Note 30 8GB/128GB - Android 13 - 6.78"...
# 130         Redmi A2+ 3GB - 64GB 5000mAh 10W fast charging...
# 131         Redmi note 12 8GB RAM -128GB ROM PTA APPROVED ...
# 132         Tecno SPARK 10 PRO 8GB RAM - 256GB ROM PTA APP...
# 133         Like New Phones - Used Apple iPhone SE 2nd Gen...
# 134         Redmi 12C 4GB RAM + 128GB ROM PTA Approved Mob...
# ...

# %%
page5
# Out:
#                                                  Product Name  \
# Product_ID
# 161         itel A60s 6.6″ HD+ Display | 8+128GB Storage |...
# 162         Tecno CAMON 20 8GB RAM-256GB ROM 5000MAH BATTE...
# 163         Samsung Galaxy A04s 4GB - 128GB OFFICIAL PTA A...
# 164                       OPPO A17 4GB + 64GB 5000mAh Battery
# 165         Tecno Camon 20 - 8GB/256GB - 64 MP Camera - 50...
# 166         Original Vivo Y85 with Box & Charger - Dual Si...
# 167         Redmi Note 12 Pro (8GB-256GB) PTA Approved Wit...
# 168         Oppo A57 - 5.2" HD Display - 4GB RAM - 64GB RO...
# 169         Sparx Neo X || 4GB RAM 64GB ROM || 50MP +2MP C...
# 170         Infinix Smart 7 - 64GB ROM - 4GB RAM - PTA APP...
# 171         Oppo A57 2022 - 6.5" HD Display - 4GB RAM - 64...
# 172         Redmi 12C || 4GB Ram 128GB Rom || 6.71 Inches ...
# 173         Redmi Note 12 8GB Ram 128GB Rom, Display Size ...
# 174         Redmi Note 12 || 8GB Ram 128GB Rom || 6.67 Inc...
# ...

# %%
combine = pd.concat([page1,page2,page3,page4,page5],ignore_index=False)

# %%
# Out:
#                                                  Product Name  \
# Product_ID
# 1           Samsung A14 4GB/64GB - 5000 mAh Battery - 6.6'...
# 2           Like New Phones - Used Apple iPhone X - Silver...
# 3           Infinix Note 30 Pro 8-256 GB PTA Approved With...
# 4           Redmi Note 12 8 GB RAM + 128GB ROM PTA Approve...
# 5           vivo Y17s - 6GB RAM - 128GB ROM - 5000mAh Batt...
# ...                                                       ...
# 196         Infinix Smart 7 , Back Camera 13 MP , 4GB RAM ...
# 197         Xiaomi Redmi 12 || 8GB + 128GB || 6.79" IPS Di...
# 198         VGOTEL Note 23 || 8GB+8GB RAM 256GB ROM || 500...
# 199         Xiaomi Note 12 , 8GB RAM 128GB ROM , 50MP Main...
# 200         Tecno Camon 20 - 8GB RAM 256GB ROM - 6.67" AMO...
#
#                                                  Product_Link Product_Brand  \
# Product_ID
# 1           https://www.daraz.pk/products/samsung-a14-4gb6...      No Brand
# ...

# %%
combine.to_excel('All-Data.xlsx')

# %%
rev1 = pd.read_excel('Page1 reviews_and_specs.xlsx',index_col='Product_ID')
rev2 = pd.read_excel('Page2 reviews_and_specs.xlsx',index_col='Product_ID')
rev3 = pd.read_excel('Page3 reviews_and_specs.xlsx',index_col='Product_ID')
rev4= pd.read_excel('Page4 reviews_and_specs.xlsx',index_col='Product_ID')
rev5 = pd.read_excel('Page5 reviews_and_specs.xlsx',index_col='Product_ID')
rev1.drop(columns='Unnamed: 0',inplace=True)
rev2.drop(columns='Unnamed: 0',inplace=True)
rev3.drop(columns='Unnamed: 0',inplace=True)
rev4.drop(columns='Unnamed: 0',inplace=True)
rev5.drop(columns='Unnamed: 0',inplace=True)

# %%
# Out:
#                                                 Product_Specs  \
# Product_ID
# 1           • Samsung A14 with 4GB/64GB memory.• 5000 mAh ...
# 2           Model: Apple\nModel: iPhone X\nBattery Health ...
# 3           Release Date2023-05-22SIM SupportDual SIM (Nan...
# 4           Redmi Note 12 8GB RAM + 128GB ROM PTA Approved...
# 5           Processor MediaTek Helio G85\nRAM 6 GB\nROM 12...
# 6           ColourXanh Tia Chop = Lightning Blueđen = Blac...
# 7           Display: 6.52” HD+ Dot Drop displayResolution:...
# 8                          50MP. Android 12.5000 mah battery.
# 9           Model: Apple\nModel: iPhone X\nBattery Health ...
# 10          • Infinix Note 30 with 6.78" display and 5000m...
# 11          Display: 6.52” HD+ Dot Drop display1600 x 720 ...
# 12          Display6.67" AMOLED DotDisplayRefresh rate: 12...
# 13          Starry Black/Pearl White/Magic Skin(Black and ...
# 14          Brand : Apple\nModel : iPhone SE\nBattery Heal...
# ...

# %%
# c_rev = pd.concat([rev1,rev2,rev3,rev4,rev5],ignore_index=False)

# %%
c_rev
# Out:
#                                                 Product_Specs  \
# Product_ID
# 1           • Samsung A14 with 4GB/64GB memory.• 5000 mAh ...
# 2           Model: Apple\nModel: iPhone X\nBattery Health ...
# 3           Release Date2023-05-22SIM SupportDual SIM (Nan...
# 4           Redmi Note 12 8GB RAM + 128GB ROM PTA Approved...
# 5           Processor MediaTek Helio G85\nRAM 6 GB\nROM 12...
# ...                                                       ...
# 196         General FeaturesRelease Date2023-02-09SIM Supp...
# 197         BuildOSAndroid 13 OS UIMIUI 14 Dimensions168.6...
# 198         General FeaturesRelease Date2023-11-14SIM Supp...
# 199         ProcessorCPUOcta-core (4 x 2.8 GHz Cortex-A73 ...
# 200         pre { white-space: pre-wrap; }• Tecno Camon 20...
#
#                                               Product_Reviews
# Product_ID
# 1           ['Mobile without mobile warranty card, charger...
# 2                                                          []
# ...

# %%
# c_rev.to_excel('All-Reviews_Specs.xlsx')

# %%
# !pip install mysql-connector-python

# %%
data_base= connect(host= 'localhost',user='root',passwd='niggasingh')
cur = data_base.cursor()
query = 'show databases'
cur.execute(query)
data_base = cur.fetchall()

for data in data_base:
    print(data)
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)
# ('testdatabase',)
# ('world',)

# %%
## 
data_base = connect(host='localhost',user='root',passwd='niggasingh',database='sakila')

cur = data_base.cursor()
query =

# %%
# import mysql.connector

# # Connect to the MySQL server (replace 'username', 'password', 'localhost', 'database' with your actual values)
# connection = mysql.connector.connect(
#     host='localhost',
#     user='username',
#     password='password',
#     database='database'
# )

# # Create a cursor object to execute SQL queries
# cursor = connection.cursor()

# # Create the Products and Reviews tables
# cursor.execute("""
#     CREATE TABLE Products (
#         ProductID INT PRIMARY KEY,
#         Name VARCHAR(255) NOT NULL,
#         Price DECIMAL(10, 2) NOT NULL,
#         Brand VARCHAR(100)
#     )
# """)

# cursor.execute("""
#     CREATE TABLE Reviews (
#         ReviewID INT PRIMARY KEY,
#         ReviewText TEXT,
#         Rating INT,
#         ProductID INT,
#         FOREIGN KEY (ProductID) REFERENCES Products(ProductID)
#     )
# """)

# # Insert data into the tables
# cursor.execute("INSERT INTO Products (ProductID, Name, Price, Brand) VALUES (1, 'Laptop', 999.99, 'XYZ Electronics')")
# cursor.execute("INSERT INTO Products (ProductID, Name, Price, Brand) VALUES (2, 'Smartphone', 499.99, 'ABC Mobiles')")

# cursor.execute("INSERT INTO Reviews (ReviewID, ReviewText, Rating, ProductID) VALUES (1, 'Great laptop!', 5, 1)")
# cursor.execute("INSERT INTO Reviews (ReviewID, ReviewText, Rating, ProductID) VALUES (2, 'Fast and reliable.', 4, 1)")
# cursor.execute("INSERT INTO Reviews (ReviewID, ReviewText, Rating, ProductID) VALUES (3, 'Good value for money.', 4, 2)")

# # Commit the changes
# connection.commit()

# # Query the data
# cursor.execute("SELECT * FROM Products")
# products_data = cursor.fetchall()

# cursor.execute("SELECT * FROM Reviews")
# reviews_data = cursor.fetchall()

# # Close the cursor and connection
# cursor.close()
# connection.close()

# # Display the data
# print("Products:")
# print(products_data)
# print("\nReviews:")
# print(reviews_data)

# %% [markdown]
# # START RUNNING FROM HERE SHIFT +ENTER

# %%
df = pd.read_excel('All-Data.xlsx',index_col='Product_ID')
df
# Out:
#                                                  Product Name  \
# Product_ID
# 1           Samsung A14 4GB/64GB - 5000 mAh Battery - 6.6'...
# 2           Like New Phones - Used Apple iPhone X - Silver...
# 3           Infinix Note 30 Pro 8-256 GB PTA Approved With...
# 4           Redmi Note 12 8 GB RAM + 128GB ROM PTA Approve...
# 5           vivo Y17s - 6GB RAM - 128GB ROM - 5000mAh Batt...
# ...                                                       ...
# 196         Infinix Smart 7 , Back Camera 13 MP , 4GB RAM ...
# 197         Xiaomi Redmi 12 || 8GB + 128GB || 6.79" IPS Di...
# 198         VGOTEL Note 23 || 8GB+8GB RAM 256GB ROM || 500...
# 199         Xiaomi Note 12 , 8GB RAM 128GB ROM , 50MP Main...
# 200         Tecno Camon 20 - 8GB RAM 256GB ROM - 6.67" AMO...
#
#                                                  Product_Link Product_Brand  \
# Product_ID
# 1           https://www.daraz.pk/products/samsung-a14-4gb6...      No Brand
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 1 to 200
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Product Name    200 non-null    object
#  1   Product_Link    200 non-null    object
#  2   Product_Brand   200 non-null    object
#  3   Product_Price   200 non-null    int64
#  4   Product_Rating  200 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 9.4+ KB

# %%
df['Product_Rating'].replace('Null',np.nan,inplace=True)

# %%
df['Product_Rating']=df['Product_Rating'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 1 to 200
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Product Name    200 non-null    object
#  1   Product_Link    200 non-null    object
#  2   Product_Brand   200 non-null    object
#  3   Product_Price   200 non-null    int64
#  4   Product_Rating  192 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 9.4+ KB

# %%
Highest_rated = df[df['Product_Rating'] ==5]
Names_of_Highest_Rated = list(Highest_rated[:5]['Product Name'])
Links_of_Highest_Rated = list(Highest_rated[:5]['Product_Link'])
Price_of_Highest_Rated = list(Highest_rated[:5]['Product_Price'])
# print(Names_of_Highest_Rated,Price_of_Highest_Rated,Links_of_Highest_Rated,sep='\n')

# %%
average_price = df['Product_Price'].mean()
average_rating = df['Product_Rating'].mean()

# %%
rev = pd.read_excel('All-Reviews_Specs.xlsx',index_col='Product_ID')
combined = pd.merge(df,rev,how='outer',on='Product_ID')
combined['Product_Reviews'] = combined['Product_Reviews'].replace('[]',np.nan)
# combined['Product_Reviews'] = combined['Product_Reviews'].replace('')
combined
# Out:
#                                                  Product Name  \
# Product_ID
# 1           Samsung A14 4GB/64GB - 5000 mAh Battery - 6.6'...
# 2           Like New Phones - Used Apple iPhone X - Silver...
# 3           Infinix Note 30 Pro 8-256 GB PTA Approved With...
# 4           Redmi Note 12 8 GB RAM + 128GB ROM PTA Approve...
# 5           vivo Y17s - 6GB RAM - 128GB ROM - 5000mAh Batt...
# ...                                                       ...
# 196         Infinix Smart 7 , Back Camera 13 MP , 4GB RAM ...
# 197         Xiaomi Redmi 12 || 8GB + 128GB || 6.79" IPS Di...
# 198         VGOTEL Note 23 || 8GB+8GB RAM 256GB ROM || 500...
# 199         Xiaomi Note 12 , 8GB RAM 128GB ROM , 50MP Main...
# 200         Tecno Camon 20 - 8GB RAM 256GB ROM - 6.67" AMO...
#
#                                                  Product_Link Product_Brand  \
# Product_ID
# 1           https://www.daraz.pk/products/samsung-a14-4gb6...      No Brand
# ...

# %%
# connection = connect(user='root',password ='niggasingh',host='localhost')
# cursor = connection.cursor()
# db_query = 'CREATE DATABASE project'
# cursor.execute(db_query)

# connection.commit()

# %%
# cursor.close()
# connection.close()

# %%
# connection = connect(user='root',password='niggasingh',host='localhost',database='project')
# cursor = connection.cursor()

# %%
combined['Product Name lower'] = combined['Product Name'].str.lower()
combined
# Out:
#                                                  Product Name  \
# Product_ID
# 1           Samsung A14 4GB/64GB - 5000 mAh Battery - 6.6'...
# 2           Like New Phones - Used Apple iPhone X - Silver...
# 3           Infinix Note 30 Pro 8-256 GB PTA Approved With...
# 4           Redmi Note 12 8 GB RAM + 128GB ROM PTA Approve...
# 5           vivo Y17s - 6GB RAM - 128GB ROM - 5000mAh Batt...
# ...                                                       ...
# 196         Infinix Smart 7 , Back Camera 13 MP , 4GB RAM ...
# 197         Xiaomi Redmi 12 || 8GB + 128GB || 6.79" IPS Di...
# 198         VGOTEL Note 23 || 8GB+8GB RAM 256GB ROM || 500...
# 199         Xiaomi Note 12 , 8GB RAM 128GB ROM , 50MP Main...
# 200         Tecno Camon 20 - 8GB RAM 256GB ROM - 6.67" AMO...
#
#                                                  Product_Link Product_Brand  \
# Product_ID
# 1           https://www.daraz.pk/products/samsung-a14-4gb6...      No Brand
# ...

# %%
# engine = create_engine('mysql+pympsql://root:niggasingh@localhost/project')

# %%
combined['Product_Specs'].replace('\n', ' ',inplace=True)
combined['Product_Specs']
# Out:
# Product_ID
# 1      • Samsung A14 with 4GB/64GB memory.• 5000 mAh ...
# 2      Model: Apple\nModel: iPhone X\nBattery Health ...
# 3      Release Date2023-05-22SIM SupportDual SIM (Nan...
# 4      Redmi Note 12 8GB RAM + 128GB ROM PTA Approved...
# 5      Processor MediaTek Helio G85\nRAM 6 GB\nROM 12...
#                              ...
# 196    General FeaturesRelease Date2023-02-09SIM Supp...
# 197    BuildOSAndroid 13 OS UIMIUI 14 Dimensions168.6...
# 198    General FeaturesRelease Date2023-11-14SIM Supp...
# 199    ProcessorCPUOcta-core (4 x 2.8 GHz Cortex-A73 ...
# 200    pre { white-space: pre-wrap; }• Tecno Camon 20...
# Name: Product_Specs, Length: 200, dtype: object

# %%
def phones_check(tokens):
    phone_count = 0
    phonelistindex = []
    found_phones = []
    tokens = [string.lower() if string.isalpha() else string for string in tokens]
#     print(tokens)
    phones_names = ['samsung','xiaomi','redmi','itel','iphone','tecno','vivo','oppo','infinix']
    for i in range(len(phones_names)):
        if(phones_names[i] in tokens):
            phone_count+=1
            phonelistindex.append(i)
    for i in range(len(phonelistindex)):
        found_phones.append(phones_names[phonelistindex[i]])
    return found_phones
test = 'hello i need phones Samsung and Redmi under price range 40k'
t1 = word_tokenize(test)
phones_check(t1)
# Out:
# ['samsung', 'redmi']

# %%
def rep_xxk_w_0s(tokens):
    ntokens = []
    
    for token in tokens:
        matched_tok = re.match(r'^(\d+)k$', token,re.IGNORECASE)
        if matched_tok:
            val = int(matched_tok.group(1)) * 1000
            ntokens.append(str(val))
        else:
            ntokens.append(token)
    
    return ntokens
test = 'I need 50K wale  phones'
rep_xxk_w_0s(word_tokenize(test))
# Out:
# ['I', 'need', '50000', 'wale', 'phones']

# %%
def contains_dig(tokens):
    str_with_dig=[]
    for token in tokens:
        if isinstance(token, str) and re.fullmatch(r'\d+', token):
            str_with_dig.append(token)
    if len(str_with_dig) > 0:
        return str_with_dig
    else:
        return []

# %%
def specific_check(tokens,phone):
    stpwords = stopwords.words('english')
    for i in range(len(tokens)):
        if tokens[i] == phone:
            try:
                if tokens[i+1] not in stpwords:
                    return True
                else:
                    return False
            except IndexError:
                pass

# %%
def mp_case(tokens):
    for token in tokens:
        match = re.match(r'\b\d+mp\b',token,re.IGNORECASE)
        print(match)
        if match:
            print('yes')
            return True
        else:
            print('no')
            return False
def gb_case(tokens):
    for token in tokens:
        match

# %%
def gen_response(u_input):
    response = ''
    indices = []
    tokens = word_tokenize(u_input)
    tokens = [string.lower() if string.isalpha() else string for string in tokens]
    ## converts to lowercase
    tokens = rep_xxk_w_0s(tokens) ## replaces the 40k with 40000
    print(tokens)
    digits = contains_dig(tokens)
#     print("DIgits",digits)
#     print('tokens',tokens)
#     if (mp_case(tokens) == True):
#             ind = 0
#             for i in range(len(tokens)):
#                 if ('mp' in tokens) or ('MP' in tokens):
#                     ind = i
#                     print(tokens[i])
#                     break
#             req_phone = combined.loc[(combined['Product_Specs'].str.contains(tokens[ind], case=False)) |(combined['Product Name lower'].str.contains(tokens[ind], case=False))].index.tolist()
#             indices = req_phone
    

    
    if len(digits) == 1:          ## if tokens contain digits and only one digit
        
#         elif ()
        if 'top' in tokens and len(phones_in_str) == 1:
            phones_in_str = phones_check(tokens)
            req_phone = combined[combined['Product_Specs'].str.contains(phones_in_str[0], case=False)]['Product_Price'].nlargest(5).index.tolist()
            indices = req_phone
            print(indices)
        elif 'top' in tokens:
            phones_in_str = phones_check(tokens)
            req_phone = combined['Product_Price'].nlargest(5).index.tolist()
            indices = req_phone
        
        elif (('over'in tokens)or ('above' in tokens)) and (len(phones_check(tokens)) == 1) and int(digits[0]) > 5:  ## check a product by its price and 
            thres = int(digits[0])
            phones_in_str = phones_check(tokens)
            req_phone = combined.loc[(combined['Product_Price'] >= thres) & (combined['Product Name lower'].str.contains(phones_in_str[0]))].index.tolist()
            indices = req_phone
#             print(indices)
        elif (('under'in tokens) or ('below' in tokens)) and (len(phones_check(tokens)) == 1) and int(digits[0]) > 5:
            thres = int(digits[0])
            phones_in_str = phones_check(tokens)
            req_phone = combined.loc[(combined['Product_Price'] <= thres) & (combined['Product Name lower'].str.contains(phones_in_str[0]))].index.tolist()
            indices = req_phone
#             print(indices)
        elif (('under'in tokens) or ('below' in tokens)) and (len(phones_check(tokens)) == 2) and int(digits[0]) > 5:
            thres = int(digits[0])
            phones_in_str = phones_check(tokens)
            req_phone = combined.loc[(combined['Product_Price'] <= thres) & ((combined['Product Name lower'].str.contains(phones_in_str[0]))|(combined['Product Name lower'].str.contains(phones_in_str[1])))].index.tolist()
            indices = req_phone
#             print(indices)
        elif (('over'in tokens) or ('above' in tokens)) and (len(phones_check(tokens)) == 2) and int(digits[0]) > 5:
            thres = int(digits[0])
            phones_in_str = phones_check(tokens)
            req_phone = combined.loc[(combined['Product_Price'] >= thres) & ((combined['Product Name lower'].str.contains(phones_in_str[0]))|(combined['Product Name lower'].str.contains(phones_in_str[1])))].index.tolist()
            indices = req_phone
#             print(indices)
        elif (('over' in tokens) or ('above' in tokens)) and (len(phones_check(tokens)) == 2) and int(digits[0]) <= 5:
            thres = int(digits[0])
            phones_in_str = phones_check(tokens)
            req_phone = combined.loc[(combined['Product_Rating'] >= thres) & ((combined['Product Name lower'].str.contains(phones_in_str[0]))|(combined['Product Name lower'].str.contains(phones_in_str[1])))].index.tolist()
            indices = req_phone
        elif (('under' in tokens) or ('below' in tokens)) and (len(phones_check(tokens)) == 2) and int(digits[0]) <= 5:
            thres = int(digits[0])
            phones_in_str = phones_check(tokens)
            req_phone = combined.loc[(combined['Product_Rating'] <= thres) & ((combined['Product Name lower'].str.contains(phones_in_str[0]))|(combined['Product Name lower'].str.contains(phones_in_str[1])))].index.tolist()
            indices = req_phone
        elif (('over' in tokens) or ('above' in tokens)) and (len(phones_check(tokens)) == 1) and int(digits[0]) <= 5:
            thres = int(digits[0])
            phones_in_str = phones_check(tokens)
            req_phone = combined.loc[(combined['Product_Rating'] >= thres) & ((combined['Product Name lower'].str.contains(phones_in_str[0])))].index.tolist()
            indices = req_phone
        elif (('under' in tokens) or ('below' in tokens)) and (len(phones_check(tokens)) == 1) and int(digits[0]) <= 5:
            thres = int(digits[0])
            phones_in_str = phones_check(tokens)
            req_phone = combined.loc[(combined['Product_Rating'] <= thres) & ((combined['Product Name lower'].str.contains(phones_in_str[0])))].index.tolist()
            indices = req_phone
        
        elif (('over' in tokens )or ('above' in tokens)) and ('rating' in tokens) and ('price' not in tokens):
            thres = float(digits[0])
            rating = combined.loc[combined['Product_Rating'] >= thres].index.tolist()
            indices = rating
            print(rating,'this me')
        elif (('under' in tokens )or ('below' in tokens)) and ('rating' in tokens) and ('price' not in tokens):
            thres = float(digits[0])
            rating = combined.loc[combined['Product_Rating'] <= thres].index.tolist()
            indices = rating
            print(rating,'this is me')
        elif (('over' in tokens ) or ('above' in tokens)) and ('rating' not in tokens):
            thres = float(digits[0])
            rating = combined.loc[combined['Product_Price'] >= thres].index.tolist()
            indices = rating
            print(rating,'tis I')
        elif ('rating' in tokens) and ('price' not in tokens):
            thres = float(digits[0])
            rating = combined.loc[combined['Product_Rating'] == thres].index.tolist()
            indices = rating
        elif (('under' in tokens) or ('below' in tokens)) and 'rating' not in tokens:
            thres = float(digits[0])
            ## puts all the product ids in one list containing all the ids less than the threshold value
            prices = combined.loc[combined['Product_Price'] < thres].index.tolist()
            indices = prices
            print(indices,'hi') ## returns index value
        
        
    elif digits == None or len(digits) == 0:  ## if there are no digits in the input string by the user
        phones_in_str = phones_check(tokens)
        
            ## if only 1 phone name is present in the string
#             print(indices)
        if 'top' in tokens and len(phones_in_str) == 1:
            phones_in_str = phones_check(tokens)
            req_phone = combined[combined['Product_Specs'].str.contains(phones_in_str[0], case=False)]['Product_Price'].nlargest(5).index.tolist()
            indices = req_phone
            print(indices)
        elif 'top' in tokens:
            phones_in_str = phones_check(tokens)
            req_phone = combined['Product_Price'].nlargest(5).index.tolist()
            indices = req_phone
        elif len(phones_in_str) == 1:
            req_phone = combined.loc[combined['Product Name lower'].str.contains(phones_in_str[0])].index.tolist()
            indices = req_phone
        elif len(phones_in_str) == 2:
            req_phone = combined.loc[combined['Product Name lower'].str.contains(phones_in_str[0]) 
                                     | combined['Product Name lower'].str.contains(phones_in_str[1])].index.tolist()
            indices = req_phone
            ## if 2 phones names are present in the text
            print(indices)
        elif len(phones_in_str) == 3:
            req_phone = combined.loc[combined['Product Name lower'].str.contains(phones_in_str[0]) 
                                     | combined['Product Name lower'].str.contains(phones_in_str[1])
                                     | combined['Product Name lower'].str.contains(phones_in_str[2])].index.tolist()
            indices = req_phone
#             print(indices)
        if len(phones_in_str) == 1 and specific_check(tokens,phones_in_str[0]):
            whole_name = ''
            for i in range(len(tokens)):
                if tokens[i] == phones_in_str[0]:
                    if tokens[i+1] != 'phones':
                        whole_name = tokens[i]+" "+tokens[i+1]
                        break
                    else:
                        whole_name = tokens[i]
#             print(whole_name)
            req_phone = combined.loc[combined['Product Name lower'].str.contains(whole_name)].index.tolist()
            indices = req_phone
#             print(indices)
            
    elif len(digits) == 2:
        phones_in_str = phones_check(tokens)
        
        if (('between' in tokens) or ('range' in tokens)) and ((int(digits[0])) > 5 and (int(digits[1]) > 5)) and (len(phones_in_str) == 1):
            req_phone = combined.loc[(combined['Product_Price'] >= int(digits[0])) & (combined['Product_Price'] <= int(digits[1])) & (combined['Product Name lower'].str.contains(phones_in_str[0]))].index.tolist()
            indices = req_phone
        elif (('between' in tokens) or ('range' in tokens)) and ((int(digits[0])) > 5 and (int(digits[1]) > 5)) and (len(phones_in_str) == 2):
            req_phone = combined.loc[(combined['Product_Price'] >= int(digits[0])) & (combined['Product_Price'] <= int(digits[1])) & ((combined['Product Name lower'].str.contains(phones_in_str[0]))|(combined['Product Name lower'].str.contains(phones_in_str[1])))].index.tolist()
            indices = req_phone
        elif (('between' in tokens) or ('range' in tokens)) and ((int(digits[0])) > 5 and (int(digits[1]) > 5)):
            req_phone = combined.loc[(combined['Product_Price'] >= int(digits[0])) & (combined['Product_Price'] <= int(digits[1]))].index.tolist()
            indices = req_phone
            print(indices)
        elif (('over' in tokens) or ('above' in tokens)) and ((int(digits[0]) > 5) and (int(digits[1]) <= 5)) and (len(phones_in_str) == 1):
            req_phone = combined.loc[(combined['Product_Price'] >= int(digits[0])) & (combined['Product_Rating'] >= int(digits[1])) & (combined['Product Name lower'].str.contains(phones_in_str[0]))].index.tolist()
            indices = req_phone
        elif (('over' in tokens) or ('above' in tokens)) and ((int(digits[0]) <= 5) and (int(digits[1]) > 5)) and (len(phones_in_str) == 1):
            req_phone = combined.loc[(combined['Product_Price'] >= int(digits[1])) & (combined['Product_Rating'] >= int(digits[0])) & (combined['Product Name lower'].str.contains(phones_in_str[0]))].index.tolist()
            indices = req_phone
        elif (('under' in tokens) or ('below' in tokens)) and ((int(digits[0]) > 5) and (int(digits[1]) <= 5)) and (len(phones_in_str) == 1):
            req_phone = combined.loc[(combined['Product_Price'] <= int(digits[0])) & (combined['Product_Rating'] >= int(digits[1])) & (combined['Product Name lower'].str.contains(phones_in_str[0]))].index.tolist()
            indices = req_phone
        elif (('under' in tokens) or ('below' in tokens)) and ((int(digits[0]) <= 5) and (int(digits[1]) > 5)) and (len(phones_in_str) == 1):
            req_phone = combined.loc[(combined['Product_Price'] <= int(digits[1])) & (combined['Product_Rating'] >= int(digits[0])) & (combined['Product Name lower'].str.contains(phones_in_str[0]))].index.tolist()
            indices = req_phone
    elif len(digits) == 3:
        phones_in_str = phones_check(tokens)
        if (('between' in tokens) or ('range' in tokens)) and (int(digits[0]) > 5) and (int(digits[1]) > 5) and (int(digits[2]) <= 5) and (len(phones_in_str) ==1):
            req_phone = combined.loc[(combined['Product_Price'] >= int(digits[0]))&(combined['Product_Price'] <= int(digits[1])) & (combined['Product_Rating'] >= int(digits[2])) & (combined['Product Name lower'].str.contains(phones_in_str[0]))].index.tolist()
            indices = req_phone
        elif (('between' in tokens) or ('range' in tokens)) and (int(digits[0]) <= 5) and (int(digits[1]) > 5) and (int(digits[2]) > 5) and (len(phones_in_str) ==1):
            req_phone = combined.loc[(combined['Product_Rating'] >= int(digits[0]))&(combined['Product_Price'] >= int(digits[1])) & (combined['Product_Price'] <= int(digits[2])) & (combined['Product Name lower'].str.contains(phones_in_str[0]))].index.tolist()
            indices = req_phone
        elif (('between' in tokens) or ('range' in tokens)) and (int(digits[0]) <= 5) and (int(digits[1]) > 5) and (int(digits[2]) > 5) and (len(phones_in_str) ==2):
            req_phone = combined.loc[(combined['Product_Rating'] >= int(digits[0]))&(combined['Product_Price'] >= int(digits[1])) & (combined['Product_Price'] <= int(digits[2])) & (combined['Product Name lower'].str.contains(phones_in_str[0])) | (combined['Product Name lower'].str.contains(phones_in_str[1]))].index.tolist()
            indices = req_phone
        elif (('between' in tokens) or ('range' in tokens)) and (int(digits[0]) > 5) and (int(digits[1]) > 5) and (int(digits[2]) <= 5) and (len(phones_in_str) ==2):
            req_phone = combined.loc[(combined['Product_Price'] >= int(digits[0]))&(combined['Product_Price'] <= int(digits[1])) & (combined['Product_Rating'] >= int(digits[2])) & (combined['Product Name lower'].str.contains(phones_in_str[0])) | (combined['Product Name lower'].str.contains(phones_in_str[1]))].index.tolist()
            indices = req_phone
        elif (('between' in tokens) or ('range' in tokens)) and (int(digits[0]) > 5) and (int(digits[1]) > 5) and (int(digits[2]) <= 5) and (len(phones_in_str) == 0):
            req_phone = combined.loc[(combined['Product_Price'] >= int(digits[0]))&(combined['Product_Price'] <= int(digits[1])) & (combined['Product_Rating'] >= int(digits[2])) ].index.tolist()
            indices = req_phone
    print(indices)
    return indices

        
    

gen_response('show me phones of top phones of samsung')
# Out:
# ['show', 'me', 'phones', 'of', 'top', 'phones', 'of', 'samsung']
# [18, 137, 19, 138, 28]
# [18, 137, 19, 138, 28]
# [18, 137, 19, 138, 28]

# %%
indices = gen_response('show me phones over price 200k of xiaomi')
res = combined.loc[indices,['Product Name','Product_Price','Product_Rating','Product_Link','Product_Specs']]
# Out:
# ['show', 'me', 'phones', 'over', 'price', '200000', 'of', 'xiaomi']
# [51, 89, 175]

# %%
res
# Out:
#                                                  Product Name  Product_Price  \
# Product_ID
# 51          Xiaomi 13T Pro - 6.67" Inch AMOLED Display - 1...         238499
# 89          Xiaomi 13T Pro - 6.67" Inch AMOLED Display - 1...         238499
# 175         Xiaomi 13T Pro - 6.67" Inch AMOLED Display - 1...         238499
#
#             Product_Rating                                       Product_Link  \
# Product_ID
# 51                     4.0  https://www.daraz.pk/products/xiaomi-13t-pro-6...
# 89                     4.0  https://www.daraz.pk/products/xiaomi-13t-pro-6...
# 175                    4.0  https://www.daraz.pk/products/xiaomi-13t-pro-6...
#
#                                                 Product_Specs
# Product_ID
# 51          1 Year Brand Warranty\nDisplay : 6.67" Inch FH...
# 89          1 Year Brand Warranty\nDisplay : 6.67" Inch FH...
# 175         1 Year Brand Warranty\nDisplay : 6.67" Inch FH...

# %%
largest_price = combined.nlargest(combined['Product_Price'].nunique(),'Product_Price').index.tolist()
largest_price = largest_price[9:14]
res = combined.loc[largest_price,'Product Name'].tolist()

res
# Out:
# ['Xiaomi 13T - 6.67" Inch Display - 12GB RAM - 256GB ROM',
#  'vivo V29 5G - 12GB RAM - 256GB ROM - 50MP OIS Camera - In-Display Fingerprint - 80W Flashcharge',
#  'vivo V29 5G - 12GB RAM - 256GB ROM - 50MP OIS Camera - In-Display Fingerprint - 80W Flashcharge',
#  'Samsung Galaxy A54 8GB+256GB',
#  'Samsung Galaxy A54 8GB+256GB']

# %%
app = Flask(__name__,template_folder=r'C:\Users\alpha\OneDrive\Documents\TNT\PAI\Project\templates')

@app.route('/')
def home():
    datadic = {'names':Names_of_Highest_Rated,
               'links':Links_of_Highest_Rated,
               'prices': Price_of_Highest_Rated}
#     if request.method == 'POST':
#         searched_thing = request.form.get('search','Def val')
#         indices = gen_response(searched_thing)
#         print(searched_thing)
#         res = combined.loc[indices,['Product Name','Product_Price','Product_Rating','Product_Link','Product_Specs']]
#         response_data = res.to_dict(orient='records')
#         print('adfklsjdfklajfklajsdfjlaksdjfljsldfkjalsjflaskj')
        
    
    return render_template('main.html',names=datadic['names'],prices = datadic['prices'],links=datadic['links'],average_price= average_price,
                           average_ratings=average_rating)

@app.route('/search',methods=['POST','GET'])
def search():
    query = request.form['search']
    indices = gen_response(query)
#     print(query)
    res = combined.loc[indices,['Product Name','Product_Price','Product_Rating','Product_Link','Product_Specs']].values.tolist()
    
    return render_template('response.html',response = res)
if __name__ == '__main__':
    app.run(port=8000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8000
# Press CTRL+C to quit
# 127.0.0.1 - - [10/Jan/2024 01:18:16] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jan/2024 01:18:19] "POST /search HTTP/1.1" 200 -
# ['iphone']
# [2, 9, 14, 16, 17, 25, 32, 72, 110, 122, 133, 135, 136, 144, 150, 179, 186]
